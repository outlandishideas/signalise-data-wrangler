# %% [markdown]
# # Google Calendar and people API
# Calendar part based on https://medium.com/@ArchTaqi/google-calendar-api-in-your-application-without-oauth-consent-screen-4fcc1f8eb380

# %% [markdown]
# # Installation

# %%
# !pip install google-api-python-client
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.7/dist-packages (1.12.8)
# Requirement already satisfied: google-auth>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.35.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (0.0.4)
# Requirement already satisfied: google-api-core<2dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.26.3)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: six<2dev,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (3.17.3)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (57.4.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2018.9)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (1.53.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (2.23.0)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client) (21.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth>=1.16.0->google-api-python-client) (4.2.4)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=14.3->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.4.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2dev,>=1.21.0->google-api-python-client) (2021.10.8)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.5 MB/s
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.2

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Set up Google stuff
#
# * enable site wide delegation https://admin.google.com/ac/owl/domainwidedelegation and enable all the scopes below
# * create an app https://console.cloud.google.com/home/dashboard
# * create a service user and save their credentials to `service-account.json`

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from datetime import datetime, timedelta
import pandas as pd

# %%
SCOPES = [
          'https://www.googleapis.com/auth/calendar',
          'https://www.googleapis.com/auth/contacts.readonly',
          'https://www.googleapis.com/auth/userinfo.email',
          'https://www.googleapis.com/auth/directory.readonly',
          'https://www.googleapis.com/auth/contacts.other.readonly',


          ]
SERVICE_ACCOUNT_FILE = 'service-account.json' # You should make it an environment variable
CREDENTIALS = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)
SUBJECT = 'harry@outlandishideas.co.uk'

# %% [markdown]
# # People/contacts

# %%
def get_people_service(subject):
  delegated_credentials = CREDENTIALS.with_subject(subject)
  people_service =  build('people', 'v1', credentials=delegated_credentials) 
  return people_service

# %%
def get_all_directory(subject):
  people = get_people_service(subject).people()
  #https://googleapis.github.io/google-api-python-client/docs/dyn/people_v1.people.html
  all_people = []
  request = people.listDirectoryPeople(readMask='names,emailAddresses', sources=['DIRECTORY_SOURCE_TYPE_DOMAIN_CONTACT', 'DIRECTORY_SOURCE_TYPE_DOMAIN_PROFILE'])
  response = request.execute()
  while response is not None:
    all_people.extend(response['people'])
    request = people.listDirectoryPeople_next(request, response)
    if not request:
      break
    response = request.execute()
  return all_people

all_directory = get_all_directory(SUBJECT)
len(all_directory)
# Out:
# 32

# %%
pd.DataFrame.from_records(pd.json_normalize(all_directory, record_path=['emailAddresses'], meta=['resourceName', 'etag']))
# Out:
#                             value  ...                   etag
# 0       ant@outlandishideas.co.uk  ...  %EgcBAgkuNz0+GgMBBwg=
# 1              ant@outlandish.com  ...  %EgcBAgkuNz0+GgMBBwg=
# 2     harry@outlandishideas.co.uk  ...  %EgcBAgkuNz0+GgMBBwg=
# 3            harry@outlandish.com  ...  %EgcBAgkuNz0+GgMBBwg=
# 4     login@outlandishideas.co.uk  ...  %EgcBAgkuNz0+GgMBBwg=
# ..                            ...  ...                    ...
# 67           koyan@outlandish.com  ...  %EgcBAgkuNz0+GgMBBwg=
# 68  aydarus@outlandishideas.co.uk  ...  %EgcBAgkuNz0+GgMBBwg=
# 69         aydarus@outlandish.com  ...  %EgcBAgkuNz0+GgMBBwg=
# 70   jannik@outlandishideas.co.uk  ...  %EgcBAgkuNz0+GgMBBwg=
# 71          jannik@outlandish.com  ...  %EgcBAgkuNz0+GgMBBwg=
#
# [72 rows x 10 columns]

# %%
def get_all_contacts(subject):
  all_contacts = []
  #https://googleapis.github.io/google-api-python-client/docs/dyn/people_v1.otherContacts.html
  other_contacts = get_people_service(subject).otherContacts()
  request = other_contacts.list(readMask='names,emailAddresses')
  response = request.execute()
  while response is not None:
    all_contacts.extend(response['otherContacts'])
    request = other_contacts.list_next(request, response)
    if not request:
      break
    response = request.execute()
  return all_contacts

all_contacts = get_all_contacts(SUBJECT)
len(all_contacts)
# Out:
# 3078

# %%
all_people = all_contacts + all_directory
all_addresses = pd.json_normalize(all_people, record_path=['emailAddresses'], meta=['etag', 'resourceName'])
all_addresses
# Out:
#                               value  ...                        resourceName
# 0            choccybic@hortmail.com  ...  otherContacts/c5422114772956436875
# 1           jack.bond@parliament.uk  ...  otherContacts/c4852397293170430076
# 2                   masim@vizob.com  ...  otherContacts/c6099300501218632515
# 3              awgandrews@gmail.com  ...  otherContacts/c7811082304361379697
# 4     aledward@camdennewjournal.com  ...  otherContacts/c5409403520849142012
# ...                             ...  ...                                 ...
# 3221           koyan@outlandish.com  ...        people/107766348220368688776
# 3222  aydarus@outlandishideas.co.uk  ...        people/105180486244090489201
# 3223         aydarus@outlandish.com  ...        people/105180486244090489201
# 3224   jannik@outlandishideas.co.uk  ...        people/108373280952820605674
# 3225          jannik@outlandish.com  ...        people/108373280952820605674
#
# [3226 rows x 10 columns]

# %% [markdown]
# # Calendar events

# %%
def get_calendar_service(subject):
  delegated_credentials = CREDENTIALS.with_subject(subject)
  calendar_service =  build('calendar', 'v3', credentials=delegated_credentials) 
  return calendar_service

# %% [markdown]
# ## Get A User Calendar Events

# %%
#https://developers.google.com/calendar/api/v3/reference/events/list

def get_events(subject_email, days_past =0, days_ahead =90):
  start = (datetime.utcnow() - timedelta(days=days_past)).isoformat() + 'Z' # 'Z' indicates UTC time
  end = (datetime.utcnow() + timedelta(days=days_ahead)).isoformat() + 'Z'
  all_events = []
  events = get_calendar_service(subject_email).events()
  request = events.list(calendarId=subject_email,timeMin=start,timeMax=end,orderBy='startTime',singleEvents=True)
  response = request.execute()
  while response is not None:
    all_events.extend(response['items'])
    request = events.list_next(request, response)
    if not request:
      break
    response = request.execute()
  return all_events

all_events = get_events(SUBJECT, days_past = 10, days_ahead = 50)
len(all_events)
# Out:
# 123

# %%
events = pd.DataFrame.from_records(all_events)
events
# Out:
#                kind                etag  ... guestsCanModify attachments
# 0    calendar#event  "3272605166770000"  ...             NaN         NaN
# 1    calendar#event  "3270823555962000"  ...             NaN         NaN
# 2    calendar#event  "3261700724464000"  ...             NaN         NaN
# 3    calendar#event  "3270823555962000"  ...             NaN         NaN
# 4    calendar#event  "3272898334660000"  ...             NaN         NaN
# ..              ...                 ...  ...             ...         ...
# 118  calendar#event  "3271711566086000"  ...             NaN         NaN
# 119  calendar#event  "3261700724464000"  ...             NaN         NaN
# 120  calendar#event  "3269521193398000"  ...            True         NaN
# 121  calendar#event  "3239415127884000"  ...             NaN         NaN
# 122  calendar#event  "3274318471138000"  ...             NaN         NaN
#
# [123 rows x 24 columns]

# %%
all_addresses.query('`metadata.source.type` == "DOMAIN_PROFILE"')
# Out:
#                               value  ...                  resourceName
# 3154      ant@outlandishideas.co.uk  ...  people/116681969587251687791
# 3155             ant@outlandish.com  ...  people/116681969587251687791
# 3156    harry@outlandishideas.co.uk  ...  people/111615362159996029011
# 3157           harry@outlandish.com  ...  people/111615362159996029011
# 3158    login@outlandishideas.co.uk  ...  people/102365591721057997115
# ...                             ...  ...                           ...
# 3221           koyan@outlandish.com  ...  people/107766348220368688776
# 3222  aydarus@outlandishideas.co.uk  ...  people/105180486244090489201
# 3223         aydarus@outlandish.com  ...  people/105180486244090489201
# 3224   jannik@outlandishideas.co.uk  ...  people/108373280952820605674
# 3225          jannik@outlandish.com  ...  people/108373280952820605674
#
# [72 rows x 10 columns]

# %%
everyones_events = []
for address in all_addresses.query('`metadata.source.type` == "DOMAIN_PROFILE"').value:
  if "outlandish.com" not in address:
    continue
  print(address)
  everyones_events.extend(get_events(address))

everyones_events
# Out:
# ant@outlandish.com
# harry@outlandish.com
# login@outlandish.com
# toggl@outlandish.com
# matt@outlandish.com
# pete@outlandish.com
# maddy@outlandish.com
# thomas@outlandish.com
# kayleigh@outlandish.com
# ella@outlandish.com
# aaron@outlandish.com
# ricky@outlandish.com
# noel@outlandish.com
# nico@outlandish.com
# everything@outlandish.com
# *@outlandish.com
# admin@outlandish.com
# schoolcuts@outlandish.com
# sangerdata@outlandish.com
# abi@outlandish.com
# caitlin@outlandish.com
# michael@outlandish.com
# doug@outlandish.com
# mateus@outlandish.com
# polly@outlandish.com
# lucy@outlandish.com
# richard@outlandish.com
# jannikko@outlandish.com
# droom@outlandish.com
# rasmus@outlandish.com
# ras@outlandish.com
# amil@outlandish.com
# koyan@outlandish.com
# aydarus@outlandish.com
# jannik@outlandish.com
# [{'attendees': [{'email': 'harry@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'kayleigh@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True},
#    {'email': 'stuart.hill@prospect.org.uk', 'responseStatus': 'needsAction'},
#    {'email': 'koyan@outlandish.com', 'responseStatus': 'accepted'}],
#   'created': '2021-11-09T16:19:56.000Z',
#   'creator': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'description': "Let's have an all-team retro to reflect on what we did this sprint, continue what's working and improve what isn't quite right. \n\nStuart, if this time doesn't work, could you suggest a few other slots? Ideally not on Friday. \n\nThanks",
#   'end': {'dateTime': '2021-11-18T14:45:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3273996328948000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NTFqMGtvbDlxNzNob3VzaDJka2lobWtzcHIgYW50QG91dGxhbmRpc2hpZGVhcy5jby51aw',
#   'iCalUID': '51j0kol9q73housh2dkihmkspr@google.com',
#   'id': '51j0kol9q73housh2dkihmkspr',
#   'kind': 'calendar#event',
#   'location': 'https://whereby.com/outlandish-prospect',
#   'organizer': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-18T14:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Outlandish x Prospect retro with Stuart',
#   'updated': '2021-11-15T17:42:44.474Z'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-20T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTExMTlUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211119T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-19T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-19T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-21T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTExMjBUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211120T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-20T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-20T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-22T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTExMjFUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211121T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-21T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-21T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-23T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTExMjJUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211122T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-22T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-22T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'email': 'harry@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'displayName': 'Everyone',
#     'email': 'everyone@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2018-02-12T18:23:00.000Z',
#   'creator': {'email': 'harry@outlandishideas.co.uk'},
#   'end': {'dateTime': '2021-11-25T14:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3272040696442000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NWVib2hlNzIwOHRmNGR2djlwc21rMjYyanFfMjAyMTExMjVUMTMwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '5ebohe7208tf4dvv9psmk262jq_R20210225T130000@google.com',
#   'id': '5ebohe7208tf4dvv9psmk262jq_20211125T130000Z',
#   'kind': 'calendar#event',
#   'location': 'https://whereby.com/outlandish-meeting-room',
#   'organizer': {'email': 'harry@outlandishideas.co.uk'},
#   'originalStartTime': {'dateTime': '2021-11-25T13:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '5ebohe7208tf4dvv9psmk262jq_R20210225T130000',
#   'reminders': {'useDefault': True},
#   'sequence': 1,
#   'start': {'dateTime': '2021-11-25T13:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Outlandish Monthly Update Meeting ',
#   'transparency': 'transparent',
#   'updated': '2021-11-04T10:05:48.221Z'},
#  {'attendees': [{'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True},
#    {'email': 'abi@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'kayleigh@outlandish.com', 'responseStatus': 'accepted'},
#    {'email': 'amil@outlandish.com', 'responseStatus': 'accepted'},
#    {'displayName': 'Pete Burden',
#     'email': 'pwb@seestep.com',
#     'responseStatus': 'needsAction'}],
#   'conferenceData': {'conferenceId': 'xbi-qerv-gxa',
#    'conferenceSolution': {'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png',
#     'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet'},
#    'entryPoints': [{'entryPointType': 'video',
#      'label': 'meet.google.com/xbi-qerv-gxa',
#      'uri': 'https://meet.google.com/xbi-qerv-gxa'},
#     {'entryPointType': 'phone',
#      'label': '+1 662-532-9017',
#      'pin': '785065439',
#      'regionCode': 'US',
#      'uri': 'tel:+1-662-532-9017'}],
#    'signature': 'AGirE/LjXQK8v0mChEqslfacjb9G'},
#   'created': '2021-11-16T16:58:48.000Z',
#   'creator': {'email': 'abi@outlandishideas.co.uk'},
#   'end': {'dateTime': '2021-11-25T15:45:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3274314843106000"',
#   'eventType': 'default',
#   'hangoutLink': 'https://meet.google.com/xbi-qerv-gxa',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MmdxZ2lpMXR2ZWpnOTRzZmQ5NmRnbXBrcGsgYW50QG91dGxhbmRpc2hpZGVhcy5jby51aw',
#   'iCalUID': '2gqgii1tvejg94sfd96dgmpkpk@google.com',
#   'id': '2gqgii1tvejg94sfd96dgmpkpk',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'abi@outlandishideas.co.uk'},
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-25T14:15:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Policy session',
#   'updated': '2021-11-17T13:57:01.553Z'},
#  {'attendees': [{'email': 'kayleigh@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2021-10-20T20:07:17.000Z',
#   'creator': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'description': 'Happy to move this to a Weds if that suits you better :)\n\nSuggested locations for catch ups: \n- Somewhere that sells nice savoury food\n- Somewhere that sells nice sweet food\n- Somewhere sunny \n- Somewhere that sells nice hot drinks\n- Online',
#   'end': {'dateTime': '2021-11-25T17:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3269520876194000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MXRrdmpoYjM0MzZucWUza2M2dHNjMW5kaHNfMjAyMTExMjVUMTYwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '1tkvjhb3436nqe3kc6tsc1ndhs@google.com',
#   'id': '1tkvjhb3436nqe3kc6tsc1ndhs_20211125T160000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'originalStartTime': {'dateTime': '2021-11-25T16:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '1tkvjhb3436nqe3kc6tsc1ndhs',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-25T16:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Buddy catch up ',
#   'updated': '2021-10-20T20:07:18.097Z'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-27T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTExMjZUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211126T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-26T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-26T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-28T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTExMjdUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211127T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-27T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-27T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-29T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTExMjhUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211128T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-28T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-28T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-30T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTExMjlUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211129T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-29T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-29T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-04T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTEyMDNUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211203T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-03T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-03T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-05T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTEyMDRUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211204T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-04T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-04T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-06T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTEyMDVUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211205T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-05T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-05T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-07T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTEyMDZUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211206T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-06T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-06T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-11T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTEyMTBUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211210T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-10T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-10T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-12T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTEyMTFUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211211T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-11T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-11T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-13T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTEyMTJUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211212T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-12T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-12T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-14T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTEyMTNUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211213T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-13T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-13T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'email': 'kayleigh@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2021-10-20T20:07:17.000Z',
#   'creator': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'description': 'Happy to move this to a Weds if that suits you better :)\n\nSuggested locations for catch ups: \n- Somewhere that sells nice savoury food\n- Somewhere that sells nice sweet food\n- Somewhere sunny \n- Somewhere that sells nice hot drinks\n- Online',
#   'end': {'dateTime': '2021-12-16T17:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3269520876194000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MXRrdmpoYjM0MzZucWUza2M2dHNjMW5kaHNfMjAyMTEyMTZUMTYwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '1tkvjhb3436nqe3kc6tsc1ndhs@google.com',
#   'id': '1tkvjhb3436nqe3kc6tsc1ndhs_20211216T160000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'originalStartTime': {'dateTime': '2021-12-16T16:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '1tkvjhb3436nqe3kc6tsc1ndhs',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-16T16:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Buddy catch up ',
#   'updated': '2021-10-20T20:07:18.097Z'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-18T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTEyMTdUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211217T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-17T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-17T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-19T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTEyMThUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211218T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-18T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-18T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-20T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTEyMTlUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211219T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-19T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-19T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-21T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTEyMjBUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211220T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-20T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-20T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'email': 'harry@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'displayName': 'Everyone',
#     'email': 'everyone@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2018-02-12T18:23:00.000Z',
#   'creator': {'email': 'harry@outlandishideas.co.uk'},
#   'end': {'dateTime': '2021-12-23T14:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3274212211312000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NWVib2hlNzIwOHRmNGR2djlwc21rMjYyanFfMjAyMTEyMjNUMTMwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '5ebohe7208tf4dvv9psmk262jq_R20210225T130000@google.com',
#   'id': '5ebohe7208tf4dvv9psmk262jq_20211223T130000Z',
#   'kind': 'calendar#event',
#   'location': 'https://whereby.com/outlandish-meeting-room',
#   'organizer': {'email': 'harry@outlandishideas.co.uk'},
#   'originalStartTime': {'dateTime': '2021-12-23T13:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '5ebohe7208tf4dvv9psmk262jq_R20210225T130000',
#   'reminders': {'useDefault': True},
#   'sequence': 1,
#   'start': {'dateTime': '2021-12-23T13:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Outlandish Monthly Update Meeting ',
#   'transparency': 'transparent',
#   'updated': '2021-11-16T23:41:45.656Z'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-25T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTEyMjRUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211224T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-24T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-24T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-26T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMTEyMjVUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20211225T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-25T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-25T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-27T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMTEyMjZUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20211226T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-26T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-26T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-12-28T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMTEyMjdUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20211227T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-27T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-27T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-01T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMTEyMzFUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20211231T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-12-31T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2021-12-31T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-02T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMjAxMDFUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20220101T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2022-01-01T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-01T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:37.106Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:22.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-03T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841891813000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3BldGEyYzk4cmdlMXQycGk1YW5mc2ZvdW9fMjAyMjAxMDJUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7peta2c98rge1t2pi5anfsfouo@google.com',
#   'id': '7peta2c98rge1t2pi5anfsfouo_20220102T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2022-01-02T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7peta2c98rge1t2pi5anfsfouo',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-02T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:29.574Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:07.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-04T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841895743000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N21qM2wwZmNlYTRubTlhNDd2MnNtdXA5dXBfMjAyMjAxMDNUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7mj3l0fcea4nm9a47v2smup9up@google.com',
#   'id': '7mj3l0fcea4nm9a47v2smup9up_20220103T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2022-01-03T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '7mj3l0fcea4nm9a47v2smup9up',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-03T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:48.271Z',
#   'visibility': 'public'},
#  {'attendees': [{'email': 'kayleigh@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2021-10-20T20:07:17.000Z',
#   'creator': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'description': 'Happy to move this to a Weds if that suits you better :)\n\nSuggested locations for catch ups: \n- Somewhere that sells nice savoury food\n- Somewhere that sells nice sweet food\n- Somewhere sunny \n- Somewhere that sells nice hot drinks\n- Online',
#   'end': {'dateTime': '2022-01-06T17:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3269520876194000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=MXRrdmpoYjM0MzZucWUza2M2dHNjMW5kaHNfMjAyMjAxMDZUMTYwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '1tkvjhb3436nqe3kc6tsc1ndhs@google.com',
#   'id': '1tkvjhb3436nqe3kc6tsc1ndhs_20220106T160000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'kayleigh@outlandishideas.co.uk'},
#   'originalStartTime': {'dateTime': '2022-01-06T16:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '1tkvjhb3436nqe3kc6tsc1ndhs',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-06T16:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Buddy catch up ',
#   'updated': '2021-10-20T20:07:18.097Z'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:33.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-08T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841887861000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHRkcGkzcmtsMWczc3BzdW1iZnBicGYycXZfMjAyMjAxMDdUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '4tdpi3rkl1g3spsumbfpbpf2qv@google.com',
#   'id': '4tdpi3rkl1g3spsumbfpbpf2qv_20220107T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2022-01-07T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '4tdpi3rkl1g3spsumbfpbpf2qv',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-07T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
#   'updated': '2021-10-19T18:49:14.452Z',
#   'visibility': 'public'},
#  {'attendees': [{'displayName': 'ant@outlandishideas.co.uk',
#     'email': 'ant@outlandishideas.co.uk',
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2021-07-13T10:35:49.000Z',
#   'creator': {'email': 'ant@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2022-01-09T00:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3260841926190000"',
#   'eventType': 'outOfOffice',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=M2Nta2Z0ZmFkM2FqNHQ3NTRwZzFwMjhjbWZfMjAyMjAxMDhUMDAwMDAwWiBhbnRAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '3cmkftfad3aj4t754pg1p28cmf@google.com',
#   'id': '3cmkftfad3aj4t754pg1p28cmf_20220108T000000Z',
#   'kind': 'calendar#event',
#   'organizer': {'displayName': 'Unknown Organizer',
#    'email': 'unknownorganizer@calendar.google.com'},
#   'originalStartTime': {'dateTime': '2022-01-08T00:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '3cmkftfad3aj4t754pg1p28cmf',
#   'reminders': {'useDefault': False},
#   'sequence': 0,
#   'start': {'dateTime': '2022-01-08T00:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Non-working day',
# ...
#   'reminders': {'useDefault': True},
#   'sequence': 1,
#   'start': {'dateTime': '2021-11-19T17:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'NBR Editorial meeting',
#   'updated': '2021-11-02T17:54:14.853Z'},
#  {'attendees': [{'email': 'harry@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2020-04-15T18:47:53.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-19T18:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3261700723486000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NW02NnU1MjRyMTZmbTg3cHFrYjM2cDhwb21fMjAyMTExMTlUMTc1MDAwWiBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': '5m66u524r16fm87pqkb36p8pom@google.com',
#   'id': '5m66u524r16fm87pqkb36p8pom_20211119T175000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'originalStartTime': {'dateTime': '2021-11-19T17:50:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '5m66u524r16fm87pqkb36p8pom',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-19T17:50:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Toggl Woggl Wobbl!',
#   'updated': '2021-09-05T13:59:21.743Z'},
#  {'created': '2021-11-16T22:51:13.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'end': {'date': '2021-11-23'},
#   'etag': '"3274206147680000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=N3Zqa2pxMTlmNDJsbWs3am5hdnBkamU1Mm8gcG9sbHlAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#   'iCalUID': '7vjkjq19f42lmk7jnavpdje52o@google.com',
#   'id': '7vjkjq19f42lmk7jnavpdje52o',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'reminders': {'overrides': [{'method': 'popup', 'minutes': 10}],
#    'useDefault': False},
#   'sequence': 0,
#   'start': {'date': '2021-11-22'},
#   'status': 'confirmed',
#   'transparency': 'transparent',
#   'updated': '2021-11-16T22:51:13.840Z'},
#  {'attendees': [{'email': 'chris.lowis@gofreerange.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'kayleigh@outlandish.com', 'responseStatus': 'accepted'},
#    {'email': 'lucy@infactcoop.com', 'responseStatus': 'accepted'},
#    {'email': 'maddy@outlandish.com', 'responseStatus': 'needsAction'},
#    {'email': 'james@lazyatom.com', 'responseStatus': 'needsAction'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted',
#     'self': True},
#    {'email': 'helen@principlesix.coop', 'responseStatus': 'needsAction'},
#    {'email': 'sion@principlesix.coop', 'responseStatus': 'accepted'},
#    {'email': 'richard@principlesix.coop', 'responseStatus': 'needsAction'}],
#   'created': '2021-05-06T15:31:18.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'description': '──────────<br><br>Outlandish is inviting you to a scheduled Zoom meeting.<br><br>Join Zoom Meeting<br><a href="https://us02web.zoom.us/j/82297438398?pwd=WDd2S2FVTGlSdGk1SGRLN1Y1NkY5dz09">https://us02web.zoom.us/j/82297438398?pwd=WDd2S2FVTGlSdGk1SGRLN1Y1NkY5dz09</a><br><br>Meeting ID: 822 9743 8398<br>Passcode: 395905<br>One tap mobile<br>+12532158782,,82297438398#,,,,*395905# US (Tacoma)<br>+13017158592,,82297438398#,,,,*395905# US (Washington DC)<br><br>Dial by your location<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 253 215 8782 US (Tacoma)<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 301 715 8592 US (Washington DC)<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 312 626 6799 US (Chicago)<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 346 248 7799 US (Houston)<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 669 900 6833 US (San Jose)<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;+1 929 205 6099 US (New York)<br>Meeting ID: 822 9743 8398<br>Passcode: 395905<br>Find your local number: <a href="https://us02web.zoom.us/u/kbPvroFvP5">https://us02web.zoom.us/u/kbPvroFvP5</a><br><br><br>──────────',
#   'end': {'dateTime': '2021-11-22T14:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3268222657866000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=ZG4ybmZidXA1amFuaTM2YzJxa3FnZGloZHBfMjAyMTExMjJUMTMwMDAwWiBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': 'dn2nfbup5jani36c2qkqgdihdp@google.com',
#   'id': 'dn2nfbup5jani36c2qkqgdihdp_20211122T130000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'originalStartTime': {'dateTime': '2021-11-22T13:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': 'dn2nfbup5jani36c2qkqgdihdp',
#   'reminders': {'useDefault': True},
#   'sequence': 1,
#   'start': {'dateTime': '2021-11-22T13:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'SPACE4 Governance Working Group',
#   'updated': '2021-10-13T07:48:48.933Z'},
#  {'attendees': [{'displayName': 'Wilson, Caroline',
#     'email': 'caroline.wilson@islington.gov.uk',
#     'responseStatus': 'needsAction'},
#    {'email': 'd.racionzer@hced.co.uk', 'responseStatus': 'needsAction'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True},
#    {'displayName': 'Shaikh, Asima',
#     'email': 'asima.shaikh@islington.gov.uk',
#     'responseStatus': 'needsAction'},
#    {'displayName': 'Folaranmi, Funmi',
#     'email': 'funmi.folaranmi@islington.gov.uk',
#     'responseStatus': 'needsAction'}],
#   'created': '2021-11-08T16:27:27.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'description': '\n________________________________________________________________________________\nMicrosoft Teams meeting\nJoin on your computer or mobile app\nClick here to join the meeting<https://teams.microsoft.com/l/meetup-join/19%3ameeting_NGU3ZjI5NTYtZTRmNS00MGQ4LWFmOTgtMjE4ZjE3M2YzNTk5%40thread.v2/0?context=%7b%22Tid%22%3a%225513a223-7abe-42d3-b161-c06abc51cb2e%22%2c%22Oid%22%3a%22ea7c0b9b-05e7-445c-be9b-ca318ee12f95%22%7d>\nLearn More<https://aka.ms/JoinTeamsMeeting> | Meeting options<https://teams.microsoft.com/meetingOptions/?organizerId=ea7c0b9b-05e7-445c-be9b-ca318ee12f95&tenantId=5513a223-7abe-42d3-b161-c06abc51cb2e&threadId=19_meeting_NGU3ZjI5NTYtZTRmNS00MGQ4LWFmOTgtMjE4ZjE3M2YzNTk5@thread.v2&messageId=0&language=en-US>\n________________________________________________________________________________\n\nThis e-mail is intended for the addressee only. If you have received it in error, please contact the sender and delete the material from your computer. Please be aware that information in this email may be confidential, legally privileged and/or copyright protected.\n',
#   'end': {'dateTime': '2021-11-22T16:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3274003527452000"',
#   'eventType': 'default',
#   'guestsCanInviteOthers': False,
#   'htmlLink': 'https://www.google.com/calendar/event?eid=',
#   'iCalUID': '040000008200E00074C5B7101A82E0080000000000C2C363BDD4D701000000000000000010000000AFF44BA480258A4BA85241C0689125ED',
#   'id': '_60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34h9g60s30c1g60o30c1g60o46ci36cr36gi48gq48dpg64o30c1g60o30c1g60o30c1g60o32c1g60o30c1g8534cd1k890j8e1g68qjgg9k890jgd9i6gok6c1m70sj2chl8l20_20211122T150000Z',
#   'kind': 'calendar#event',
#   'location': 'Microsoft Teams Meeting',
#   'organizer': {'displayName': 'Habtegebrel, Hermela',
#    'email': 'hermela.habtegebrel@islington.gov.uk'},
#   'originalStartTime': {'dateTime': '2021-11-22T15:00:00Z',
#    'timeZone': 'Europe/London'},
#   'privateCopy': True,
#   'recurringEventId': '_60q30c1g60o30e1i60o4ac1g60rj8gpl88rj2c1h84s34h9g60s30c1g60o30c1g60o46ci36cr36gi48gq48dpg64o30c1g60o30c1g60o30c1g60o32c1g60o30c1g8534cd1k890j8e1g68qjgg9k890jgd9i6gok6c1m70sj2chl8l20',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-22T15:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Cooperate Islington- Steering Group ',
#   'updated': '2021-11-15T18:42:43.726Z'},
#  {'attendees': [{'email': 'harry@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted',
#     'self': True}],
#   'created': '2020-04-15T18:47:53.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-22T18:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3261700723486000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NW02NnU1MjRyMTZmbTg3cHFrYjM2cDhwb21fMjAyMTExMjJUMTc1MDAwWiBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': '5m66u524r16fm87pqkb36p8pom@google.com',
#   'id': '5m66u524r16fm87pqkb36p8pom_20211122T175000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'originalStartTime': {'dateTime': '2021-11-22T17:50:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '5m66u524r16fm87pqkb36p8pom',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-22T17:50:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Toggl Woggl Wobbl!',
#   'updated': '2021-09-05T13:59:21.743Z'},
#  {'attendees': [{'email': 'protraggs@gmail.com', 'responseStatus': 'accepted'},
#    {'email': 'terry@northboundradio.net', 'responseStatus': 'accepted'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True},
#    {'email': 'polly@northboundradio.net', 'responseStatus': 'needsAction'},
#    {'email': 'karimdanielnewton@gmail.com', 'responseStatus': 'accepted'},
#    {'email': 'chloe@northboundradio.net', 'responseStatus': 'needsAction'},
#    {'email': 'bex@salmonz.com', 'responseStatus': 'needsAction'}],
#   'conferenceData': {'conferenceId': 'kmi-fnkd-hrj',
#    'conferenceSolution': {'iconUri': 'https://fonts.gstatic.com/s/i/productlogos/meet_2020q4/v6/web-512dp/logo_meet_2020q4_color_2x_web_512dp.png',
#     'key': {'type': 'hangoutsMeet'},
#     'name': 'Google Meet'},
#    'entryPoints': [{'entryPointType': 'video',
#      'label': 'meet.google.com/kmi-fnkd-hrj',
#      'uri': 'https://meet.google.com/kmi-fnkd-hrj'},
#     {'entryPointType': 'more',
#      'pin': '3093448797500',
#      'uri': 'https://tel.meet/kmi-fnkd-hrj?pin=3093448797500'},
#     {'entryPointType': 'phone',
#      'label': '+44 20 3956 7940',
#      'pin': '783066047',
#      'regionCode': 'GB',
#      'uri': 'tel:+44-20-3956-7940'}],
#    'signature': 'AGirE/JzmAfTeZvvjYR62nIPok9/'},
#   'created': '2021-06-22T10:57:19.000Z',
#   'creator': {'email': 'terry@northboundradio.net'},
#   'description': "Quick review of shows..<br><br><b>Show:</b>&nbsp;Waking up Traggs<br><b>Guest:</b>&nbsp;TBC<br><b>Next Airing:&nbsp;</b>13'th July (1st test episode)<br><b>Blockers:</b><br><br><br><b>Show:</b>&nbsp;A Chat with Bex<br><b>Guest:</b>&nbsp;TBC<br><b>Next Airing:&nbsp;</b>TBC<br><b>Blockers:</b>",
#   'end': {'dateTime': '2021-11-23T11:45:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3255999898530000"',
#   'eventType': 'default',
#   'hangoutLink': 'https://meet.google.com/kmi-fnkd-hrj',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=NHMyYnQxZWFnNnBhazJvYzU0ZDFyc3UxajVfMjAyMTExMjNUMTExNTAwWiBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': '4s2bt1eag6pak2oc54d1rsu1j5@google.com',
#   'id': '4s2bt1eag6pak2oc54d1rsu1j5_20211123T111500Z',
#   'kind': 'calendar#event',
#   'location': 'SPACE4, 113-115 Fonthill Rd, Finsbury Park, London N4 3HH, UK',
#   'organizer': {'displayName': 'NBR Calendar',
#    'email': 'c_mh89m6esbe19gb0i6dci31npk8@group.calendar.google.com'},
#   'originalStartTime': {'dateTime': '2021-11-23T11:15:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': '4s2bt1eag6pak2oc54d1rsu1j5',
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-23T11:15:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'NBR - Community shows',
#   'updated': '2021-08-03T14:12:29.265Z'},
#  {'created': '2021-11-03T00:28:58.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-23T15:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3271798676522000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Y2xqM2NjcjNjbGltOGJiNjY4b2plYjlrYzRvamFiYjE2dGgzNGI5azZzczNhcGo1NzVpMzRkajE2ayBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': 'clj3ccr3clim8bb668ojeb9kc4ojabb16th34b9k6ss3apj575i34dj16k@google.com',
#   'id': 'clj3ccr3clim8bb668ojeb9kc4ojabb16th34b9k6ss3apj575i34dj16k',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'reminders': {'useDefault': True},
#   'sequence': 0,
#   'start': {'dateTime': '2021-11-23T14:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Oxford university open day session',
#   'updated': '2021-11-03T00:28:58.261Z'},
#  {'attendees': [{'email': 'harry@outlandish.com',
#     'responseStatus': 'needsAction'},
#    {'email': 'mateus@outlandish.com', 'responseStatus': 'needsAction'},
#    {'email': 'richard@outlandish.com', 'responseStatus': 'needsAction'},
#    {'email': 'maddy@outlandish.com', 'responseStatus': 'needsAction'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted',
#     'self': True},
#    {'email': 'abi@outlandish.com', 'responseStatus': 'accepted'}],
#   'created': '2019-10-07T16:21:59.000Z',
#   'creator': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'end': {'dateTime': '2021-11-23T16:00:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3274318424538000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=YXMxdnIxNTBvbGowNXVodW1oY3VqY3A2NGJfMjAyMTExMjNUMTUwMDAwWiBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': 'as1vr150olj05uhumhcujcp64b_R20210622T140000@google.com',
#   'id': 'as1vr150olj05uhumhcujcp64b_20211123T150000Z',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'polly@outlandishideas.co.uk', 'self': True},
#   'originalStartTime': {'dateTime': '2021-11-23T15:00:00Z',
#    'timeZone': 'Europe/London'},
#   'recurringEventId': 'as1vr150olj05uhumhcujcp64b_R20210622T140000',
#   'reminders': {'useDefault': True},
#   'sequence': 3,
#   'start': {'dateTime': '2021-11-23T15:00:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'SPACE4 circle meeting',
#   'updated': '2021-11-17T14:26:52.269Z'},
#  {'attendees': [{'email': 'harry@outlandishideas.co.uk',
#     'organizer': True,
#     'responseStatus': 'accepted'},
#    {'email': 'polly@outlandishideas.co.uk',
#     'responseStatus': 'needsAction',
#     'self': True}],
#   'created': '2021-11-16T14:48:11.000Z',
#   'creator': {'email': 'harry@outlandishideas.co.uk'},
#   'end': {'dateTime': '2021-11-23T16:30:00Z', 'timeZone': 'Europe/London'},
#   'etag': '"3274148785062000"',
#   'eventType': 'default',
#   'htmlLink': 'https://www.google.com/calendar/event?eid=Nm9zajhkYjE2OHNqZ2I5aWNwaTY0YjlrNjhwM2diOXA2b29qZ2JiM2M5aW02ZDFtNjBzNmFkOWhjOCBwb2xseUBvdXRsYW5kaXNoaWRlYXMuY28udWs',
#   'iCalUID': '6osj8db168sjgb9icpi64b9k68p3gb9p6oojgbb3c9im6d1m60s6ad9hc8@google.com',
#   'id': '6osj8db168sjgb9icpi64b9k68p3gb9p6oojgbb3c9im6d1m60s6ad9hc8',
#   'kind': 'calendar#event',
#   'organizer': {'email': 'harry@outlandishideas.co.uk'},
#   'reminders': {'useDefault': True},
#   'sequence': 1,
#   'start': {'dateTime': '2021-11-23T15:30:00Z', 'timeZone': 'Europe/London'},
#   'status': 'confirmed',
#   'summary': 'Meet Miri at Space4',
#   'updated': '2021-11-16T14:53:12.531Z'},
#  ...]

# %%
pd.DataFrame.from_records(everyones_events)
# Out:
#                 kind                etag  ... extendedProperties colorId
# 0     calendar#event  "3273996328948000"  ...                NaN     NaN
# 1     calendar#event  "3260841887861000"  ...                NaN     NaN
# 2     calendar#event  "3260841926190000"  ...                NaN     NaN
# 3     calendar#event  "3260841891813000"  ...                NaN     NaN
# 4     calendar#event  "3260841895743000"  ...                NaN     NaN
# ...              ...                 ...  ...                ...     ...
# 1729  calendar#event  "3269983814636000"  ...                NaN       2
# 1730  calendar#event  "3272934684792000"  ...                NaN     NaN
# 1731  calendar#event  "3269983991056000"  ...                NaN       6
# 1732  calendar#event  "3269983964254000"  ...                NaN       6
# 1733  calendar#event  "3269983793392000"  ...                NaN       2
#
# [1734 rows x 33 columns]

# %% [markdown]
# ## Save the data

# %%
from getpass import getpass
from sqlalchemy import create_engine, inspect
from sqlalchemy.dialects.postgresql import JSONB

# %%
def get_reporting_db():
  db_host = 'aurora-psql-general.cefrfliziigj.eu-west-1.rds.amazonaws.com'
  db_user = 'a_signalise'
  db_name = 'signalise'
  db_pass = getpass(prompt=f"Database password for user {db_user}@{db_name}")
  engine = create_engine(f"postgresql://{db_user}:{db_pass}@{db_host}/{db_name}")
  db = engine.connect()
  inspector = inspect(engine)
  return db, engine, inspector

db, engine, inspector = get_reporting_db()
# Out:
# Database password for user a_signalise@signalise··········

# %%
schema_name = 'gsuite'
db.execute(f"CREATE schema if not exists {schema_name}")
dataframes = dict(people=pd.DataFrame.from_records(all_people), events=pd.DataFrame.from_records(everyones_events))
for table_name, table in dataframes.items():
    type_convert = {}
    table = table.convert_dtypes()
    for column_name, column_type in table.dtypes.items():
        if column_type == 'object':
            type_convert[column_name] = JSONB

        dataframes[table_name] = table

    table.to_sql(name=table_name, con=db, if_exists='replace', dtype=type_convert,  schema=schema_name)

# %%
q = "CREATE SCHEMA IF NOT EXISTS reporting"
db.execute(q)

q = """
CREATE OR REPLACE VIEW reporting.events_by_attendee AS (
  select event_id, attendees->>'email', start_time, end_time, summary, description from (
select id as event_id, "start"->>'dateTime' as start_time, "end"->>'dateTime' as end_time, jsonb_array_elements(attendees) as attendees, summary, description from gsuite.events where jsonb_typeof(attendees) = 'array') as event_attendees

)
"""
db.execute(q)

# %% [markdown]
# # Editing the calendar

# %% [markdown]
# ## Create a New Calandar Event

# %%
event = service.events().get(calendarId=SUBJECT,eventId='7e1mpsisedc8l0gqo8leag56hg').execute()

# %%
event
# Out:
# {'created': '2021-11-16T10:57:42.000Z',
#  'creator': {'email': 'harry@outlandishideas.co.uk', 'self': True},
#  'end': {'date': '2021-11-17'},
#  'etag': '"3274120524300000"',
#  'eventType': 'default',
#  'htmlLink': 'https://www.google.com/calendar/event?eid=N2UxbXBzaXNlZGM4bDBncW84bGVhZzU2aGcgaGFycnlAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#  'iCalUID': '7e1mpsisedc8l0gqo8leag56hg@google.com',
#  'id': '7e1mpsisedc8l0gqo8leag56hg',
#  'kind': 'calendar#event',
#  'organizer': {'email': 'harry@outlandishideas.co.uk', 'self': True},
#  'reminders': {'overrides': [{'method': 'popup', 'minutes': 10},
#    {'method': 'email', 'minutes': 430}],
#   'useDefault': False},
#  'sequence': 0,
#  'start': {'date': '2021-11-16'},
#  'status': 'confirmed',
#  'summary': 'test event',
#  'transparency': 'transparent',
#  'updated': '2021-11-16T10:57:42.150Z'}

# %% [markdown]
# ## Delete an Event from a Calandar

# %%
event = service.events().delete(calendarId=SUBJECT,eventId='7e1mpsisedc8l0gqo8leag56hg').execute()

# %%
event
# Out:
# ''

# %% [markdown]
# ## Create an Event into a Calandar

# %%
d = datetime.utcnow().date()
tomorrow = datetime(d.year, d.month, d.day, 10)+timedelta(days=1)
start = tomorrow.isoformat()
end = (tomorrow + timedelta(hours=1)).isoformat()
body={"summary": 'Hello there, Automating calendar', 
      "description": 'Google calendar with python',
      "start": {"dateTime": start, "timeZone": 'Asia/Karachi'}, 
      "end": {"dateTime": end, "timeZone": 'Asia/Karachi'},
     }

# %%
event = service.events().insert(calendarId=SUBJECT,body=body).execute()

# %%
event
# Out:
# {'created': '2021-11-16T11:00:58.000Z',
#  'creator': {'email': 'harry@outlandishideas.co.uk', 'self': True},
#  'description': 'Google calendar with python',
#  'end': {'dateTime': '2021-11-17T06:00:00Z', 'timeZone': 'Asia/Karachi'},
#  'etag': '"3274120916978000"',
#  'eventType': 'default',
#  'htmlLink': 'https://www.google.com/calendar/event?eid=Mm12azlhNzc4c3VyNm1sZnJvdXVjMTcxMWcgaGFycnlAb3V0bGFuZGlzaGlkZWFzLmNvLnVr',
#  'iCalUID': '2mvk9a778sur6mlfrouuc1711g@google.com',
#  'id': '2mvk9a778sur6mlfrouuc1711g',
#  'kind': 'calendar#event',
#  'organizer': {'email': 'harry@outlandishideas.co.uk', 'self': True},
#  'reminders': {'useDefault': True},
#  'sequence': 0,
#  'start': {'dateTime': '2021-11-17T05:00:00Z', 'timeZone': 'Asia/Karachi'},
#  'status': 'confirmed',
#  'summary': 'Hello there, Automating calendar',
#  'updated': '2021-11-16T11:00:58.489Z'}
